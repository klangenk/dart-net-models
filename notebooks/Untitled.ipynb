# %%
import torch
from fastai.vision.all import *
import re

# %%
import os,sys,inspect
sys.path.insert(0, '..')
sys.path.insert(0, '../..')

# %%
from lib.modules.matcher import HungarianMatcher
from lib.modules.parallel import *
from lib.modules.sequential import *
from lib.modules.single_classifier import SingleClassifier
from lib.modules.matcher import HungarianMatcher
from lib.modules.parallel import *
from lib.modules.sequential import *
from lib.modules.single_classifier import SingleClassifier
from lib.label import label_field
from lib.label import *
from lib.metric import *
from lib.data import *
from lib.loss import *
from lib.loader import *
from common.image import toTensor

# %%
data = load_data(84, (480, 480), 'train', 'valid', max_rotate=0.0, exclude=[], path = '../data_rotated')

# %%
len(data.train_ds)
# Out:
# 2677580

# %%
len(data.valid_ds)
# Out:
# 5110

# %%
model = MultiDartPlus(resnet18)
learn = Learner(data, model, metrics=[my_accuracy2, my_accuracy3], splitter=splitter2, loss_func=MyLoss(), wd=0.5).to_fp16()
learn.load('480-square-12')

# %%
learn.fit_one_cycle(2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>my_accuracy2</th>
#       <th>my_accuracy3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.792963</td>
#       <td>0.688715</td>
#       <td>5:49:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.944718</td>
#       <td>0.916569</td>
#       <td>5:50:52</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('480-square-10x-1')
# Out:
# Path('models/480-square-10x-1.pth')

# %%
model = MultiDartPlus(resnet18)
learn = Learner(data, model, metrics=[my_accuracy2, my_accuracy3], splitter=splitter2, loss_func=MyLoss(), wd=0.5).to_fp16()
learn.fit_one_cycle(2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>my_accuracy2</th>
#       <th>my_accuracy3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.511053</td>
#       <td>1.482323</td>
#       <td>0.773403</td>
#       <td>0.709980</td>
#       <td>4:52:36</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.095697</td>
#       <td>0.260932</td>
#       <td>0.959790</td>
#       <td>0.939335</td>
#       <td>4:53:17</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('480-square-10x-2')
# Out:
# Path('models/480-square-10x-2.pth')

# %%
data = load_data(84, (480, 480), 'train', 'valid', max_rotate=0.0, exclude=['generated'], path = '../data_rotated')
model = MultiDartPlus(resnet18)
learn = Learner(data, model, metrics=[my_accuracy2, my_accuracy3], splitter=splitter2, loss_func=MyLoss(), wd=0.5).to_fp16()
# Out:
# /home/kevin/miniconda3/lib/python3.8/site-packages/torch/_tensor.py:1051: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  ../aten/src/ATen/native/BatchLinearAlgebra.cpp:766.)
#   ret = func(*args, **kwargs)

# %%
learn.load('480-square-10x-2')

# %%
learn.lr_find()
# Out:
# SuggestedLRs(valley=5.248074739938602e-05)

# %%
learn.fit_one_cycle(10, 1e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>my_accuracy2</th>
#       <th>my_accuracy3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.347419</td>
#       <td>0.212313</td>
#       <td>0.969363</td>
#       <td>0.953882</td>
#       <td>06:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.269205</td>
#       <td>0.172627</td>
#       <td>0.973196</td>
#       <td>0.960535</td>
#       <td>06:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.222633</td>
#       <td>0.146281</td>
#       <td>0.976835</td>
#       <td>0.966015</td>
#       <td>06:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.185329</td>
#       <td>0.141414</td>
#       <td>0.977317</td>
#       <td>0.966797</td>
#       <td>06:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
learn.save('480-square-10x-3')
# Out:
# Path('models/480-square-10x-3.pth')

# %%
learn.lr_find()
# Out:
# SuggestedLRs(valley=3.0199516913853586e-05)

# %%
learn.fit_one_cycle(5, 1e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>my_accuracy2</th>
#       <th>my_accuracy3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.043697</td>
#       <td>0.059263</td>
#       <td>0.989011</td>
#       <td>0.983431</td>
#       <td>06:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.040811</td>
#       <td>0.059178</td>
#       <td>0.990590</td>
#       <td>0.985845</td>
#       <td>06:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.038614</td>
#       <td>0.059060</td>
#       <td>0.989580</td>
#       <td>0.984540</td>
#       <td>06:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.035893</td>
#       <td>0.054900</td>
#       <td>0.990696</td>
#       <td>0.986106</td>
#       <td>06:21</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
learn.save('480-square-10x-4')
# Out:
# Path('models/480-square-10x-4.pth')

# %%
learn.lr_find()
# Out:
# SuggestedLRs(valley=3.0199516913853586e-05)

# %%
learn.fit_one_cycle(1, 1e-7)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>my_accuracy2</th>
#       <th>my_accuracy3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.035507</td>
#       <td>0.053609</td>
#       <td>0.990745</td>
#       <td>0.986106</td>
#       <td>06:21</td>
#     </tr>
#   </tbody>
# </table>

# %%
data = load_data(84, (480, 480), 'train', 'valid', max_rotate=0.0, exclude=['generated'], path = '../data_rotated')
model = MultiDartPlus(resnet18)
learn = Learner(data, model, metrics=[my_accuracy2, my_accuracy3], splitter=splitter2, loss_func=MyLoss(), wd=0.5).to_fp16()
learn.load('480-square-10x-1')
# Out:
# /home/kevin/miniconda3/lib/python3.8/site-packages/torch/_tensor.py:1051: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  ../aten/src/ATen/native/BatchLinearAlgebra.cpp:766.)
#   ret = func(*args, **kwargs)

# %%
learn.fit_one_cycle(10, 1e-4)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /home/kevin/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>my_accuracy2</th>
#       <th>my_accuracy3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.954583</td>
#       <td>0.932094</td>
#       <td>06:39</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.960751</td>
#       <td>0.942140</td>
#       <td>06:33</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.960358</td>
#       <td>0.940770</td>
#       <td>06:35</td>
#     </tr>
#     <tr>
#       <td>3</td>
# ...

# %%
learn.fit_one_cycle(10, 1e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>my_accuracy2</th>
#       <th>my_accuracy3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.467276</td>
#       <td>0.225594</td>
#       <td>0.968837</td>
#       <td>0.953229</td>
#       <td>06:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.252049</td>
#       <td>0.165218</td>
#       <td>0.975267</td>
#       <td>0.962427</td>
#       <td>06:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.220550</td>
#       <td>0.217687</td>
#       <td>0.961753</td>
#       <td>0.941944</td>
#       <td>06:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.171819</td>
#       <td>0.146859</td>
#       <td>0.977940</td>
#       <td>0.967123</td>
#       <td>06:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
learn.fit_one_cycle(10, 1e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>my_accuracy2</th>
#       <th>my_accuracy3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.272198</td>
#       <td>0.174357</td>
#       <td>0.975774</td>
#       <td>0.963666</td>
#       <td>06:28</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.209422</td>
#       <td>0.143309</td>
#       <td>0.978741</td>
#       <td>0.967776</td>
#       <td>06:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.172753</td>
#       <td>0.132765</td>
#       <td>0.978717</td>
#       <td>0.967971</td>
#       <td>06:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.154009</td>
#       <td>0.135585</td>
#       <td>0.978791</td>
#       <td>0.968558</td>
#       <td>06:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
learn.fit_one_cycle(10, 1e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>my_accuracy2</th>
#       <th>my_accuracy3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.051651</td>
#       <td>0.067982</td>
#       <td>0.987827</td>
#       <td>0.981605</td>
#       <td>06:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.108247</td>
#       <td>0.203675</td>
#       <td>0.968015</td>
#       <td>0.951729</td>
#       <td>06:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.106070</td>
#       <td>0.117001</td>
#       <td>0.982444</td>
#       <td>0.973385</td>
#       <td>06:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.096560</td>
#       <td>0.107167</td>
#       <td>0.982952</td>
#       <td>0.974690</td>
#       <td>06:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>my_accuracy2</th>
#       <th>my_accuracy3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.144757</td>
#       <td>0.890521</td>
#       <td>0.858934</td>
#       <td>0.800000</td>
#       <td>06:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.012100</td>
#       <td>0.878110</td>
#       <td>0.869393</td>
#       <td>0.807306</td>
#       <td>06:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.743861</td>
#       <td>0.425884</td>
#       <td>0.930143</td>
#       <td>0.897717</td>
#       <td>06:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.513073</td>
#       <td>0.245646</td>
#       <td>0.957833</td>
#       <td>0.938030</td>
#       <td>06:30</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
learn.lr_find()
# Out:
# SuggestedLRs(valley=2.0892961401841603e-05)

# %%
learn.fit_one_cycle(10, 1e-4)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       40.00% [4/10 25:33<38:20]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>my_accuracy2</th>
#       <th>my_accuracy3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
data = load_data(84, (480, 480), 'train', 'valid', max_rotate=0.0, exclude=['generated'], path = '../data_rotated')
model = MultiDartPlus(resnet18)
learn = Learner(data, model, metrics=[my_accuracy2, my_accuracy3], splitter=splitter2, loss_func=MyLoss(), wd=0.5).to_fp16()
learn.load('480-square-10x-1')
# Out:
# /home/kevin/miniconda3/lib/python3.8/site-packages/torch/_tensor.py:1051: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  ../aten/src/ATen/native/BatchLinearAlgebra.cpp:766.)
#   ret = func(*args, **kwargs)

# %%
learn.fit_one_cycle(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>my_accuracy2</th>
#       <th>my_accuracy3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.375860</td>
#       <td>0.428514</td>
#       <td>0.944659</td>
#       <td>0.917808</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.927715</td>
#       <td>1.086805</td>
#       <td>0.850372</td>
#       <td>0.789302</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.055369</td>
#       <td>1.081477</td>
#       <td>0.847844</td>
#       <td>0.784084</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.004016</td>
#       <td>1.161115</td>
#       <td>0.825726</td>
#       <td>0.769080</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
learn.lr_find()
# Out:
# SuggestedLRs(valley=0.00010964782268274575)

# %%
learn.fit_one_cycle(10, 1e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>my_accuracy2</th>
#       <th>my_accuracy3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.365681</td>
#       <td>0.223757</td>
#       <td>0.967583</td>
#       <td>0.950424</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.367155</td>
#       <td>0.222242</td>
#       <td>0.971724</td>
#       <td>0.956295</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.373906</td>
#       <td>0.239876</td>
#       <td>0.969613</td>
#       <td>0.953686</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.366377</td>
#       <td>0.227076</td>
#       <td>0.971742</td>
#       <td>0.956947</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
data = load_data(84, (480, 480), 'train', 'valid', max_rotate=5.0, exclude=['generated'], path = '../data_rotated')
model = MultiDartPlus(resnet18)
learn = Learner(data, model, metrics=[my_accuracy2, my_accuracy3], splitter=splitter2, loss_func=MyLoss(), wd=0.5).to_fp16()
learn.load('480-square-12-best-3')
learn.fit_one_cycle(6, 1e-5)
# Out:
# /home/kevin/miniconda3/lib/python3.8/site-packages/torch/_tensor.py:1051: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  ../aten/src/ATen/native/BatchLinearAlgebra.cpp:766.)
#   ret = func(*args, **kwargs)
# /home/kevin/miniconda3/lib/python3.8/site-packages/fastai/learner.py:56: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>my_accuracy2</th>
# ...
